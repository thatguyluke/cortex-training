# %%
# %run config.ipynb
# Out:
# 7.1.2a4
# You are already using Cortex 7.1.2a4

# %%
from cortex import Cortex, Message
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os
import sys
import json
import re
import time
import datetime
import dill
import sklearn
import sklearn2

client = Cortex.client()
exp = client.experiment('flowers/iris-predict')

exp
# Out:
#                     <style>
#                         #table1 {
#                           border: solid thin;
#                           border-collapse: collapse;
#                         }
#                         #table1 caption {
#                           padding-bottom: 0.5em;
#                         }
#                         #table1 th,
#                         #table1 td {
#                           border: solid thin;
#                           padding: 0.5rem 2rem;
#                         }
#                         #table1 td {
#                           white-space: nowrap;
#                         }
#                         #table1 td {
#                           border-style: none solid;
#                           vertical-align: top;
#                         }
#                         #table1 th {
#                           padding: 0.2em;
#                           vertical-align: middle;
#                           text-align: center;
#                         }
#                         #table1 tbody td:first-child::after {
#                           content: leader(". "); '
#                         }
#                     </style>
#                     <table id="table1">
#                         <caption><b>Experiment:</b> flowers/iris-predict</caption>
#                         <thead>
#                         <tr>
#                             <th rowspan="2">ID</th>
#                             <th rowspan="2">Date</th>
#                             <th rowspan="2">Took</th>
#                             <th colspan="4" scope="colgroup">Params</th>
#                             <th colspan="1" scope="colgroup">Metrics</th>
#                         </tr>
#                         <tr>
#
#                             <th>batch size</th>
#
#                             <th>criterion</th>
#
#                             <th>epochs</th>
#
#                             <th>model name</th>
#
#
#                             <th>score</th>
#
#                         </tr>
#                         </thead>
#                         <tbody>
#
#                             <tr>
#                             <td>x64m0fwq</td>
#                             <td>Mon, 01 Jul 2019 15:51:27 GMT</td>
#                             <td>0.32 s</td>
#
#                             <td>&#x2011;</td>
#
#                             <td>gini</td>
#
#                             <td>&#x2011;</td>
#
#                             <td>&#x2011;</td>
#
#
#                             <td>0.940000</td>
#
#                             </tr>
#
#                             <tr>
#                             <td>9z4n0fdp</td>
#                             <td>Mon, 01 Jul 2019 15:51:30 GMT</td>
#                             <td>0.44 s</td>
#
#                             <td>&#x2011;</td>
#
#                             <td>entropy</td>
#
#                             <td>&#x2011;</td>
#
#                             <td>&#x2011;</td>
#
#
#                             <td>0.940000</td>
#
#                             </tr>
#
#                             <tr>
#                             <td>qj4o0fbo</td>
#                             <td>Mon, 01 Jul 2019 15:52:13 GMT</td>
#                             <td>3.33 s</td>
#
#                             <td>3</td>
#
#                             <td>&#x2011;</td>
#
#                             <td>1</td>
#
#                             <td>adam optimizer</td>
#
#
#                             <td>0.000000</td>
#
#                             </tr>
#
#                             <tr>
#                             <td>bz4p0fmt</td>
#                             <td>Mon, 01 Jul 2019 15:52:35 GMT</td>
#                             <td>3.43 s</td>
#
#                             <td>3</td>
#
#                             <td>&#x2011;</td>
#
#                             <td>1</td>
#
#                             <td>adam optimizer</td>
#
#
#                             <td>0.000000</td>
#
#                             </tr>
#
#                             <tr>
#                             <td>yy4q0fg7</td>
#                             <td>Mon, 01 Jul 2019 16:39:57 GMT</td>
#                             <td>3.45 s</td>
#
#                             <td>3</td>
#
#                             <td>&#x2011;</td>
#
#                             <td>1</td>
#
#                             <td>adam optimizer</td>
#
#
#                             <td>0.000000</td>
#
#                             </tr>
#
#                             <tr>
#                             <td>yz4r0fhe</td>
#                             <td>Mon, 01 Jul 2019 20:29:52 GMT</td>
#                             <td>2.90 s</td>
#
#                             <td>3</td>
#
#                             <td>&#x2011;</td>
#
#                             <td>1</td>
#
#                             <td>adam optimizer</td>
#
#
#                             <td>0.000000</td>
#
#                             </tr>
#
#                             <tr>
#                             <td>sb4s0ffm</td>
#                             <td>Mon, 01 Jul 2019 20:30:57 GMT</td>
#                             <td>2.92 s</td>
#
#                             <td>3</td>
#
#                             <td>&#x2011;</td>
#
#                             <td>1</td>
#
#                             <td>adam optimizer</td>
#
#
#                             <td>0.000000</td>
#
#                             </tr>
#
#                             <tr>
#                             <td>wb4t0fjj</td>
#                             <td>Mon, 01 Jul 2019 20:31:22 GMT</td>
#                             <td>3.12 s</td>
#
#                             <td>3</td>
#
#                             <td>&#x2011;</td>
#
#                             <td>1</td>
#
#                             <td>adam optimizer</td>
#
#
#                             <td>0.000000</td>
#
#                             </tr>
#
#                             <tr>
#                             <td>l14u0f1a</td>
#                             <td>Mon, 01 Jul 2019 20:31:25 GMT</td>
#                             <td>3.77 s</td>
#
#                             <td>3</td>
#
#                             <td>

# %%
run = exp.last_run() 

#to select a specific model you want uncomment the following and comment out above then put the exp id you want from above.
#run = exp.get_run(<ID>)

model = run.get_artifact('model')

print('Run id: %s \nModel name: "%s"' %(run.id, model))
# Out:
# Using TensorFlow backend.
# Run id: 4ca40f7q
# Model name: "<function small_sgd_opt_model at 0x1268d80d0>"

# %%
builder = client.builder()
builder.action('flowers/iris-predict')\
        .with_requirements(['tensorflow>=1.12,<2',
                            'keras>=2.2.4,<3'])\
        .from_model(model, model_type='tensorflow')\
        .daemon()\
        .build()
# Out:
# Building Cortex Action (daemon): flowers/iris-predict
# Building Docker image private-registry.cortex.insights.ai/thatguyluke/flowers_iris-predict:qlnfeb2...
# Step 1/9 : FROM c12e/cortex-python36:7552534
# Step 2/9 : WORKDIR /app
# Step 3/9 : RUN pip install flask gunicorn
# Step 4/9 : RUN pip install "dill==0.2.8.2" "cortex-client==7.1.2a4"
# Step 5/9 : COPY requirements.txt .
# Step 6/9 : RUN pip install -r requirements.txt
# Step 7/9 : COPY action.py .
# Step 8/9 : EXPOSE 5000
# Removing intermediate container 68ab83af6630
# Step 9/9 : ENTRYPOINT ["gunicorn", "-b", "0.0.0.0:5000", "-t", "60", "action:app"]
# Removing intermediate container c32acd48f109
# Successfully built c9f3d918aa58
# Successfully tagged private-registry.cortex.insights.ai/thatguyluke/flowers_iris-predict:qlnfeb2
# Image private-registry.cortex.insights.ai/thatguyluke/flowers_iris-predict:qlnfeb2 built in 1.519958 seconds
# Pushing image to remote repository...
# qlnfeb2: digest: sha256:5443a72889317f75e2364584addd936486cadb5ed4eccac1b7b197b4d8337027 size: 3256
# Image private-registry.cortex.insights.ai/thatguyluke/flowers_iris-predict:qlnfeb2 pushed in 3.339448 seconds
# Cleaning up...
# Removing previous image: sha256:5ce62a23fa
#         <table>
#             <thead>
#                 <tr>
#                     <th>Name</th>
#                     <th>Version</th>
#                     <th>Type</th>
#                     <th>Kind</th>
#                     <th>Image</th>
#                     <th>Deployment Status</th>
#                 </tr>
#             </thead>
#             <tbody>
#                 <td>flowers/iris-predict</td>
#                 <td>14</td>
#                 <td>daemon</td>
#                 <td>None</td>
#                 <td>private-registry.cortex.insights.ai/thatguyluke/flowers_iris-predict:qlnfeb2</td>
#                 <td>STARTED</td>
#             </tbody>
#         </table>

# %% [markdown]
# The following cell checks the status of the action created above.  It may take a few moments for the Deployment status to change from **STARTED** to  **COMPLETED(running)**

# %%
action = client.action('flowers/iris-predict')
action
# Out:
#         <table>
#             <thead>
#                 <tr>
#                     <th>Name</th>
#                     <th>Version</th>
#                     <th>Type</th>
#                     <th>Kind</th>
#                     <th>Image</th>
#                     <th>Deployment Status</th>
#                 </tr>
#             </thead>
#             <tbody>
#                 <td>flowers/iris-predict</td>
#                 <td>14</td>
#                 <td>daemon</td>
#                 <td>None</td>
#                 <td>private-registry.cortex.insights.ai/thatguyluke/flowers_iris-predict:qlnfeb2</td>
#                 <td>COMPLETED (running)</td>
#             </tbody>
#         </table>

# %%
# !cortex experiments describe flowers/iris-predict
# Out:
# {
#   "_version": 1,
#   "name": "flowers/iris-predict",
#   "tags": [],
#   "_environmentId": "cortex/default"
# }

# %%
# %%time

params = {'columns': ['sepal_len','sepal_w','petal_len','petal_w'],
           'values': [4.9,3.1,1.5,0.2]}
frame = pd.DataFrame(params)
result = action.invoke(message=client.message(params))
print(result.payload)
# Out:
# 2019-07-30 10:58:49,085 - INFO - cortex_client.client/client: Status: 404, Message: {"success":false,"error":"No load balancer found for invoked daemon. Stack may still be initializing."}
# I0730 10:58:49.085102 4385596864 client.py:47] Status: 404, Message: {"success":false,"error":"No load balancer found for invoked daemon. Stack may still be initializing."}
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# /anaconda3/envs/luke3/lib/python3.6/site-packages/cortex/action.py in invoke(self, message, timeout)
#      40         """
#      41         action_client = ActionClient(self._connector.url, self._connector.version, self._connector.token)
# ---> 42         return Message(action_client.invoke_action(self.name, message.to_params()))
#      43
#      44     def get_deployment_status(self):
#
# /anaconda3/envs/luke3/lib/python3.6/site-packages/cortex_client/actionclient.py in invoke_action(self, action_name, params)
#     102         """
#     103         uri = self.URIs['invoke'].format(action_name=action_name)
# --> 104         return self._post_json(uri, params)
#     105
#     106     def get_logs(self, action_name) -> Dict[str, object]:
#
# /anaconda3/envs/luke3/lib/python3.6/site-packages/cortex_client/client.py in _post_json(self, uri, obj)
#      46         if r.status_code not in [requests.codes.ok, requests.codes.created]:
#      47             log.info("Status: {}, Message: {}".format(r.status_code, r.text))
# ---> 48         r.raise_for_status()
#      49         return r.json()
#      50
#
# /anaconda3/envs/luke3/lib/python3.6/site-packages/requests/models.py in raise_for_status(self)
#     938
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#     942     def close(self):
#
# HTTPError: 404 Client Error: Not Found for url: https://api.cortex.insights.ai/v3/actions/flowers/iris-predict/invoke

# %%
x = np.argmax(result.payload['values'][0])

iris_dict = {0:'Iris-setosa',1:'Iris-versicolor',2:'Iris-virginica'}

iris_dict[x]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-69d76b89e025> in <module>()
# ----> 1 x = np.argmax(result.payload['values'][0])
#       2
#       3 iris_dict = {0:'Iris-setosa',1:'Iris-versicolor',2:'Iris-virginica'}
#       4
#       5 iris_dict[x]
#
# NameError: name 'result' is not defined

# %% [markdown]
# **Create Skill Using the Action**
#
# To create a skill from the action, call the builder to get a skill builder.

# %%
skill_builder = builder.skill('flowers/iris-predict')\
     .title('Iris Flower Prediction')\
     .description('Measurement based prediction for the type of Iris flowers.')

# %% [markdown]
# A resulting schema is used by the skill builder to identify elements of the input. In this example, the schema describes the measurement values for parts of the Iris flower.

# %%
schema_name = 'flowers/iris-input-schema'

builder.schema(schema_name)\
     .title('Iris Prediction Schema Instance')\
     .from_parameters([{'name': 'values', 'type': 'array', 'format': 'float32'}]).build()

skill_builder = skill_builder.input('iris-measurement').title('Iris Measurements')\
     .use_schema(schema_name)\
     .all_routing(action, 'measurement-based-prediction').build()

# %% [markdown]
# Specify the skill construction. The construction describes the skill including a name that matches the action name and a description of the output.

# %%
skill_builder = skill_builder.output('measurement-based-prediction').title('Classification')\
    .parameter(name='IrisClass', type='array', format='float32').build()

# %% [markdown]
# With the skill builder fully specified, call to_camel so the skill’s contents can be reviewed.

# %%
skill_builder.to_camel()

# %% [markdown]
# **Publish the Skill**
#
# Invoke the builder to publish the skill. Upon publication, the skill can be used in Cortex Studio with other skills to compose agents.

# %%
skill = skill_builder.build()
print('%s (%s) v%d' % (skill.title, skill.name, skill.version))

# %% [markdown]
# # Test the skill
